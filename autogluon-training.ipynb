# %%
pip install autogluon
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting autogluon
#   Using cached autogluon-1.2-py3-none-any.whl.metadata (11 kB)
# Collecting autogluon.core==1.2 (from autogluon.core[all]==1.2->autogluon)
#   Using cached autogluon.core-1.2-py3-none-any.whl.metadata (12 kB)
# Collecting autogluon.features==1.2 (from autogluon)
#   Using cached autogluon.features-1.2-py3-none-any.whl.metadata (11 kB)
# Collecting autogluon.tabular==1.2 (from autogluon.tabular[all]==1.2->autogluon)
#   Using cached autogluon.tabular-1.2-py3-none-any.whl.metadata (14 kB)
# Collecting autogluon.multimodal==1.2 (from autogluon)
#   Using cached autogluon.multimodal-1.2-py3-none-any.whl.metadata (12 kB)
# Collecting autogluon.timeseries==1.2 (from autogluon.timeseries[all]==1.2->autogluon)
#   Using cached autogluon.timeseries-1.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<2.1.4,>=1.25.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.26.4)
# Requirement already satisfied: scipy<1.16,>=1.5.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.11.1)
# Requirement already satisfied: scikit-learn<1.5.3,>=1.4.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.5.2)
# Requirement already satisfied: networkx<4,>=3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.3)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.1.1)
# Requirement already satisfied: tqdm<5,>=4.38 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (4.67.1)
# Requirement already satisfied: requests in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.32.3)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.7.2)
# Requirement already satisfied: boto3<2,>=1.10 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.34.127)
# Collecting autogluon.common==1.2 (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon)
#   Using cached autogluon.common-1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: ray<2.40,>=2.10.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.39.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core[all]==1.2->autogluon) (16.1.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core[all]==1.2->autogluon) (0.2.7)
# Requirement already satisfied: Pillow<12,>=10.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (11.1.0)
# Requirement already satisfied: torch<2.6,>=2.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.5.1)
# Collecting lightning<2.6,>=2.2 (from autogluon.multimodal==1.2->autogluon)
#   Using cached lightning-2.5.0.post0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: transformers<5,>=4.38.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal==1.2->autogluon) (4.47.1)
# Requirement already satisfied: accelerate<1.0,>=0.34.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.34.2)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.2.2)
# Collecting evaluate<0.5.0,>=0.4.0 (from autogluon.multimodal==1.2->autogluon)
#   Using cached evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: timm<1.0.7,>=0.9.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.0.3)
# Requirement already satisfied: torchvision<0.21.0,>=0.16.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.20.1)
# Requirement already satisfied: scikit-image<0.25.0,>=0.19.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.24.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.2.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.3.0)
# Collecting nlpaug<1.2.0,>=1.1.10 (from autogluon.multimodal==1.2->autogluon)
#   Using cached nlpaug-1.1.11-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: nltk<3.9,>=3.4.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (3.8.1)
# Collecting openmim<0.4.0,>=0.3.7 (from autogluon.multimodal==1.2->autogluon)
#   Using cached openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (3.1.4)
# Requirement already satisfied: tensorboard<3,>=2.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.18.0)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.17.0)
# Requirement already satisfied: catboost<1.3,>=1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (1.2.7)
# Requirement already satisfied: spacy<3.8 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (3.7.5)
# Requirement already satisfied: lightgbm<4.6,>=4.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (4.5.0)
# Requirement already satisfied: einops<0.9,>=0.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (0.8.0)
# Requirement already satisfied: xgboost<2.2,>=1.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (2.1.3)
# Collecting fastai<2.8,>=2.3.1 (from autogluon.tabular[all]==1.2->autogluon)
#   Using cached fastai-2.7.18-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: huggingface-hub[torch] in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (0.27.0)
# Requirement already satisfied: joblib<2,>=1.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.3.2)
# Collecting pytorch-lightning (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon)
#   Using cached pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: gluonts<0.17,>=0.15.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.16.0)
# Collecting statsforecast<1.8,>=1.7.0 (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon)
#   Using cached statsforecast-1.7.8-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Collecting mlforecast==0.13.4 (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon)
#   Using cached mlforecast-0.13.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: utilsforecast<0.2.5,>=0.2.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.2.4)
# Requirement already satisfied: coreforecast==0.0.12 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.0.12)
# Collecting fugue>=0.9.0 (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon)
#   Using cached fugue-0.9.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: orjson~=3.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (3.10.7)
# Requirement already satisfied: psutil<7.0.0,>=5.7.3 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from autogluon.common==1.2->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (6.0.0)
# Requirement already satisfied: cloudpickle in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (3.1.0)
# Requirement already satisfied: fsspec in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2024.9.0)
# Requirement already satisfied: numba in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.60.0)
# Requirement already satisfied: optuna in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (4.1.0)
# Requirement already satisfied: packaging in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (23.2)
# Requirement already satisfied: window-ops in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.0.15)
# Requirement already satisfied: pyyaml in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal==1.2->autogluon) (6.0.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal==1.2->autogluon) (0.4.3)
# Requirement already satisfied: botocore<1.35.0,>=1.34.127 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (0.10.1)
# Requirement already satisfied: graphviz in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (0.20.3)
# Requirement already satisfied: plotly in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (5.23.0)
# Requirement already satisfied: six in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (1.16.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (3.2.0)
# Requirement already satisfied: dill in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (0.70.16)
# Requirement already satisfied: pip in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (24.3.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.8,>=1.5.29 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (1.7.28)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (1.0.3)
# Requirement already satisfied: triad>=0.9.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.9.8)
# Collecting adagio>=0.2.4 (from fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon)
#   Using cached adagio-0.2.6-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.9.2)
# Requirement already satisfied: toolz~=0.10 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (4.12.2)
# Requirement already satisfied: future in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.2->autogluon) (1.0.0)
# Requirement already satisfied: py4j in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.2->autogluon) (0.10.9.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.2->autogluon) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (0.18.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from lightning<2.6,>=2.2->autogluon.multimodal==1.2->autogluon) (0.11.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.8.2)
# Requirement already satisfied: gdown>=4.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (5.2.0)
# Requirement already satisfied: click in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal==1.2->autogluon) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal==1.2->autogluon) (2024.5.15)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.2->autogluon) (4.9.3)
# Requirement already satisfied: colorama in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.4.6)
# Requirement already satisfied: model-index in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.0.10)
# Requirement already satisfied: rich in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (13.7.1)
# Requirement already satisfied: tabulate in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2023.3)
# Requirement already satisfied: filelock in c:\users\ayush\appdata\roaming\python\python311\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (3.13.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (4.25.2)
# Requirement already satisfied: aiosignal in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.3.1)
# Requirement already satisfied: frozenlist in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.4.1)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (3.10.3)
# Requirement already satisfied: aiohttp-cors in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.7.0)
# Requirement already satisfied: colorful in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.4.0)
# Collecting opencensus (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon)
#   Using cached opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.21.0)
# Requirement already satisfied: smart-open in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (7.0.4)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (20.25.0)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.60.1)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.6.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2024.12.14)
# Requirement already satisfied: imageio>=2.33 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal==1.2->autogluon) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal==1.2->autogluon) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal==1.2->autogluon) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<1.5.3,>=1.4.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.12.3)
# Requirement already satisfied: setuptools in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (3.4.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from statsforecast<1.8,>=1.7.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.14.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (3.0.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from torch<2.6,>=2.2->autogluon.multimodal==1.2->autogluon) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch<2.6,>=2.2->autogluon.multimodal==1.2->autogluon) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from transformers<5,>=4.38.0->transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal==1.2->autogluon) (0.21.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal==1.2->autogluon) (0.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.3.5)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.9.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (4.12.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from numba->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.43.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.23.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.13.2->statsforecast<1.8,>=1.7.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.1.5)
# Requirement already satisfied: fs in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from triad>=0.9.7->fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.4.16)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (2.18.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (4.2.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.18.1)
# Requirement already satisfied: wrapt in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from smart-open->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.14.1)
# Requirement already satisfied: ordered-set in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.24.0)
# Requirement already satisfied: pycryptodome in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (3.21.0)
# Requirement already satisfied: openxlab in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.0.11)
# Requirement already satisfied: pywin32 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (306)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.14.0)
# Requirement already satisfied: colorlog in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.0.32)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from plotly->catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (8.3.0)
# Requirement already satisfied: Mako in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from alembic>=1.5.0->optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.3.8)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.27.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.4.2->optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (2.5)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fs->triad>=0.9.7->fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.4.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.5.1)
# Using cached autogluon-1.2-py3-none-any.whl (9.6 kB)
# Using cached autogluon.core-1.2-py3-none-any.whl (266 kB)
# Using cached autogluon.features-1.2-py3-none-any.whl (64 kB)
# Using cached autogluon.multimodal-1.2-py3-none-any.whl (429 kB)
# Using cached autogluon.tabular-1.2-py3-none-any.whl (352 kB)
# Using cached autogluon.timeseries-1.2-py3-none-any.whl (174 kB)
# Using cached autogluon.common-1.2-py3-none-any.whl (68 kB)
# Using cached mlforecast-0.13.4-py3-none-any.whl (70 kB)
# Using cached evaluate-0.4.3-py3-none-any.whl (84 kB)
# Using cached fastai-2.7.18-py3-none-any.whl (234 kB)
# Using cached fugue-0.9.1-py3-none-any.whl (278 kB)
# Using cached lightning-2.5.0.post0-py3-none-any.whl (815 kB)
# Using cached nlpaug-1.1.11-py3-none-any.whl (410 kB)
# Using cached openmim-0.3.9-py2.py3-none-any.whl (52 kB)
# Using cached statsforecast-1.7.8-cp311-cp311-win_amd64.whl (254 kB)
# Using cached pytorch_lightning-2.5.0.post0-py3-none-any.whl (819 kB)
# Using cached adagio-0.2.6-py3-none-any.whl (19 kB)
# Using cached opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
# Installing collected packages: pytorch-lightning, openmim, opencensus, nlpaug, mlforecast, adagio, lightning, fugue, evaluate, autogluon.common, statsforecast, fastai, autogluon.features, autogluon.core, autogluon.tabular, autogluon.multimodal, autogluon.timeseries, autogluon
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\ayush\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\nlpaug\\util\\selection\\randomness.py'
# Consider using the `--user` option or check the permissions.

# %%
pip install autogluon --user
# Out:
# Requirement already satisfied: autogluon in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (1.2)
# Requirement already satisfied: autogluon.core==1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core[all]==1.2->autogluon) (1.2)
# Requirement already satisfied: autogluon.features==1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon) (1.2)
# Requirement already satisfied: autogluon.tabular==1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (1.2)
# Requirement already satisfied: autogluon.multimodal==1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon) (1.2)
# Requirement already satisfied: autogluon.timeseries==1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries[all]==1.2->autogluon) (1.2)
# Requirement already satisfied: numpy<2.1.4,>=1.25.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.26.4)
# Requirement already satisfied: scipy<1.16,>=1.5.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.11.1)
# Requirement already satisfied: scikit-learn<1.5.3,>=1.4.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.5.2)
# Requirement already satisfied: networkx<4,>=3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.3)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.1.1)
# Requirement already satisfied: tqdm<5,>=4.38 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (4.67.1)
# Requirement already satisfied: requests in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.32.3)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.7.2)
# Requirement already satisfied: boto3<2,>=1.10 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.34.127)
# Requirement already satisfied: autogluon.common==1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.2)
# Requirement already satisfied: ray<2.40,>=2.10.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.39.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core[all]==1.2->autogluon) (16.1.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.core[all]==1.2->autogluon) (0.2.7)
# Requirement already satisfied: Pillow<12,>=10.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (11.1.0)
# Requirement already satisfied: torch<2.6,>=2.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.5.1)
# Requirement already satisfied: lightning<2.6,>=2.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.5.0.post0)
# Requirement already satisfied: transformers<5,>=4.38.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal==1.2->autogluon) (4.47.1)
# Requirement already satisfied: accelerate<1.0,>=0.34.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.34.2)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.4.3)
# Requirement already satisfied: timm<1.0.7,>=0.9.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.0.3)
# Requirement already satisfied: torchvision<0.21.0,>=0.16.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.20.1)
# Requirement already satisfied: scikit-image<0.25.0,>=0.19.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.24.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.2.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.1.11)
# Requirement already satisfied: nltk<3.9,>=3.4.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (3.1.4)
# Requirement already satisfied: tensorboard<3,>=2.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (2.18.0)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.multimodal==1.2->autogluon) (1.17.0)
# Requirement already satisfied: catboost<1.3,>=1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (1.2.7)
# Requirement already satisfied: spacy<3.8 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (3.7.5)
# Requirement already satisfied: lightgbm<4.6,>=4.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (4.5.0)
# Requirement already satisfied: einops<0.9,>=0.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (0.8.0)
# Requirement already satisfied: xgboost<2.2,>=1.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (2.1.3)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (2.7.18)
# Requirement already satisfied: huggingface-hub[torch] in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.tabular[all]==1.2->autogluon) (0.27.0)
# Requirement already satisfied: joblib<2,>=1.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.3.2)
# Requirement already satisfied: pytorch-lightning in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.5.0.post0)
# Requirement already satisfied: gluonts<0.17,>=0.15.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.16.0)
# Requirement already satisfied: statsforecast<1.8,>=1.7.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.7.8)
# Requirement already satisfied: mlforecast==0.13.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.13.4)
# Requirement already satisfied: utilsforecast<0.2.5,>=0.2.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.2.4)
# Requirement already satisfied: coreforecast==0.0.12 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.0.12)
# Requirement already satisfied: fugue>=0.9.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.9.1)
# Requirement already satisfied: orjson~=3.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (3.10.7)
# Requirement already satisfied: psutil<7.0.0,>=5.7.3 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from autogluon.common==1.2->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (6.0.0)
# Requirement already satisfied: cloudpickle in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (3.1.0)
# Requirement already satisfied: fsspec in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2024.9.0)
# Requirement already satisfied: numba in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.60.0)
# Requirement already satisfied: optuna in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (4.1.0)
# Requirement already satisfied: packaging in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (23.2)
# Requirement already satisfied: window-ops in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.0.15)
# Requirement already satisfied: pyyaml in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal==1.2->autogluon) (6.0.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from accelerate<1.0,>=0.34.0->autogluon.multimodal==1.2->autogluon) (0.4.3)
# Requirement already satisfied: botocore<1.35.0,>=1.34.127 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (0.10.1)
# Requirement already satisfied: graphviz in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (0.20.3)
# Requirement already satisfied: plotly in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (5.23.0)
# Requirement already satisfied: six in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (1.16.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (3.2.0)
# Requirement already satisfied: dill in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.2->autogluon) (0.70.16)
# Requirement already satisfied: pip in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (24.3.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.8,>=1.5.29 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (1.7.28)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.2->autogluon) (1.0.3)
# Requirement already satisfied: triad>=0.9.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.2.6)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.9.2)
# Requirement already satisfied: toolz~=0.10 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (4.12.2)
# Requirement already satisfied: future in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.2->autogluon) (1.0.0)
# Requirement already satisfied: py4j in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.2->autogluon) (0.10.9.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.2->autogluon) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.2->autogluon) (0.18.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from lightning<2.6,>=2.2->autogluon.multimodal==1.2->autogluon) (0.11.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.8.2)
# Requirement already satisfied: gdown>=4.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (5.2.0)
# Requirement already satisfied: click in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal==1.2->autogluon) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from nltk<3.9,>=3.4.5->autogluon.multimodal==1.2->autogluon) (2024.5.15)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.2->autogluon) (4.9.3)
# Requirement already satisfied: colorama in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.4.6)
# Requirement already satisfied: model-index in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.0.10)
# Requirement already satisfied: rich in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (13.7.1)
# Requirement already satisfied: tabulate in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2023.3)
# Requirement already satisfied: filelock in c:\users\ayush\appdata\roaming\python\python311\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (3.13.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (4.25.2)
# Requirement already satisfied: aiosignal in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.3.1)
# Requirement already satisfied: frozenlist in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray<2.40,>=2.10.0->ray[default]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.4.1)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (3.10.3)
# Requirement already satisfied: aiohttp-cors in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.7.0)
# Requirement already satisfied: colorful in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.4.0)
# Requirement already satisfied: opencensus in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.21.0)
# Requirement already satisfied: smart-open in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (7.0.4)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (20.25.0)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.60.1)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.6.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (2024.12.14)
# Requirement already satisfied: imageio>=2.33 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal==1.2->autogluon) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal==1.2->autogluon) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-image<0.25.0,>=0.19.1->autogluon.multimodal==1.2->autogluon) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<1.5.3,>=1.4.0->autogluon.core==1.2->autogluon.core[all]==1.2->autogluon) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.12.3)
# Requirement already satisfied: setuptools in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (3.4.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from statsforecast<1.8,>=1.7.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.14.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.2->autogluon) (3.0.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from torch<2.6,>=2.2->autogluon.multimodal==1.2->autogluon) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch<2.6,>=2.2->autogluon.multimodal==1.2->autogluon) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from transformers<5,>=4.38.0->transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal==1.2->autogluon) (0.21.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from transformers[sentencepiece]<5,>=4.38.0->autogluon.multimodal==1.2->autogluon) (0.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.3.5)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.9.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (4.12.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from numba->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.43.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.23.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.13.2->statsforecast<1.8,>=1.7.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.1.5)
# Requirement already satisfied: fs in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from triad>=0.9.7->fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.4.16)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (2.18.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\ayush\appdata\roaming\python\python311\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (4.2.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (0.18.1)
# Requirement already satisfied: wrapt in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from smart-open->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.14.1)
# Requirement already satisfied: ordered-set in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.24.0)
# Requirement already satisfied: pycryptodome in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (3.21.0)
# Requirement already satisfied: openxlab in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.0.11)
# Requirement already satisfied: pywin32 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (306)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.14.0)
# Requirement already satisfied: colorlog in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (2.0.32)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from plotly->catboost<1.3,>=1.2->autogluon.tabular[all]==1.2->autogluon) (8.3.0)
# Requirement already satisfied: Mako in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from alembic>=1.5.0->optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.3.8)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (2.27.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8->autogluon.tabular[all]==1.2->autogluon) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.2->autogluon) (0.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.4.2->optuna->mlforecast==0.13.4->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (2.5)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from fs->triad>=0.9.7->fugue>=0.9.0->autogluon.timeseries==1.2->autogluon.timeseries[all]==1.2->autogluon) (1.4.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.2->autogluon) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ayush\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.40,>=2.10.0; extra == "all"->autogluon.core[all]==1.2->autogluon) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %%
from autogluon.tabular import TabularPredictor

# %%
file_path = 'heart_disease_uci.csv'  
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
data = data.drop(columns=['id'])

# %%
target = 'num'

# %%
data = data.dropna(subset=[target])

# %%
train_data = data.sample(frac=0.8, random_state=42)
test_data = data.drop(train_data.index)

# %%
train_data
# Out:
#      age     sex        dataset               cp  trestbps   chol    fbs  \
# 319   36    Male        Hungary  atypical angina     120.0  166.0  False
# 377   45    Male        Hungary  atypical angina     140.0  224.0   True
# 538   48    Male        Hungary     asymptomatic     160.0  329.0  False
# 296   59    Male      Cleveland     asymptomatic     164.0  176.0   True
# 531   40  Female        Hungary     asymptomatic     150.0  392.0  False
# ..   ...     ...            ...              ...       ...    ...    ...
# 829   45    Male  VA Long Beach      non-anginal       NaN  236.0  False
# 619   47    Male    Switzerland     asymptomatic     110.0    0.0    NaN
# 784   58    Male  VA Long Beach  atypical angina     126.0    0.0   True
# 645   54    Male    Switzerland     asymptomatic     120.0    0.0  False
# 854   55    Male  VA Long Beach     asymptomatic     172.0  260.0  False
#
#               restecg  thalch  exang  oldpeak      slope   ca  \
# 319            normal   180.0  False      0.0        NaN  NaN
# 377            normal   122.0  False      0.0        NaN  NaN
# 538            normal    92.0   True      1.5       flat  NaN
# 296    lv hypertrophy    90.0  False      1.0       flat  2.0
# 531            normal   130.0  False      2.0       flat  NaN
# ..                ...     ...    ...      ...        ...  ...
# 829            normal     NaN    NaN      NaN        NaN  NaN
# 619  st-t abnormality   149.0  False      2.1  upsloping  NaN
# 784            normal   110.0   True      2.0       flat  NaN
# 645            normal   155.0  False      0.0       flat  NaN
# 854            normal    73.0  False      2.0        NaN  NaN
#
#                   thal  num
# 319                NaN    0
# 377                NaN    0
# 538                NaN    1
# 296       fixed defect    3
# 531       fixed defect    1
# ..                 ...  ...
# 829                NaN    0
# 619                NaN    2
# 784                NaN    2
# 645  reversable defect    2
# 854                NaN    3
#
# [736 rows x 15 columns]

# %%
test_data
# Out:
#      age     sex        dataset               cp  trestbps   chol    fbs  \
# 1     67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 4     41  Female      Cleveland  atypical angina     130.0  204.0  False
# 13    44    Male      Cleveland  atypical angina     120.0  263.0  False
# 14    52    Male      Cleveland      non-anginal     172.0  199.0   True
# 20    64    Male      Cleveland   typical angina     110.0  211.0  False
# ..   ...     ...            ...              ...       ...    ...    ...
# 878   69    Male  VA Long Beach     asymptomatic       NaN  210.0   True
# 896   61    Male  VA Long Beach     asymptomatic     190.0  287.0   True
# 900   57    Male  VA Long Beach     asymptomatic     122.0  264.0  False
# 912   53    Male  VA Long Beach     asymptomatic     144.0  300.0   True
# 916   62    Male  VA Long Beach   typical angina       NaN  139.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# 13             normal   173.0  False      0.0    upsloping  0.0
# 14             normal   162.0  False      0.5    upsloping  0.0
# 20     lv hypertrophy   144.0   True      1.8         flat  0.0
# ..                ...     ...    ...      ...          ...  ...
# 878  st-t abnormality     NaN    NaN      NaN          NaN  NaN
# 896    lv hypertrophy   150.0   True      2.0  downsloping  NaN
# 900    lv hypertrophy   100.0  False      0.0          NaN  NaN
# 912  st-t abnormality   128.0   True      1.5         flat  NaN
# 916  st-t abnormality     NaN    NaN      NaN          NaN  NaN
#
#                   thal  num
# 1               normal    2
# 4               normal    0
# 13   reversable defect    0
# 14   reversable defect    0
# 20              normal    0
# ..                 ...  ...
# 878                NaN    2
# 896                NaN    4
# 900                NaN    1
# 912                NaN    3
# 916                NaN    0
#
# [184 rows x 15 columns]

# %%
train_data.shape
# Out:
# (736, 15)

# %%
test_data.shape
# Out:
# (184, 15)

# %%
predictor = TabularPredictor(label=target).fit(train_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20250116_141339"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.2
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       2.54 GB / 7.33 GB (34.7%)
# Disk Space Avail:   7.99 GB / 238.04 GB (3.4%)
# 	WARNING: Available disk space is low and there is a risk that AutoGluon will run out of disk during fit, causing an exception.
# 	We recommend a minimum available disk space of 10 GB, and large datasets may require more.
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# 	presets='good'         : Good accuracy with very fast inference speed.
# 	presets='medium'       : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "C:\Users\ayush\OneDrive\autogluon\AutogluonModels\ag-20250116_141339"
# Train Data Rows:    736
# Train Data Columns: 14
# Label Column:       num
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	5 unique label values:  [0, 1, 3, 2, 4]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2584.69 MB
# 	Train Data (Original)  Memory Usage: 0.34 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 5 | ['trestbps', 'chol', 'thalch', 'oldpeak', 'ca']
# 		('int', [])    : 1 | ['age']
# 		('object', []) : 8 | ['sex', 'dataset', 'cp', 'fbs', 'restecg', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['dataset', 'cp', 'fbs', 'restecg', 'exang', ...]
# 		('float', [])     : 5 | ['trestbps', 'chol', 'thalch', 'oldpeak', 'ca']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 1 | ['sex']
# 	0.2s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.25s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 588, Val Rows: 148
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif ...
# 	0.4459	 = Validation score   (accuracy)
# 	7.79s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.4797	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 8: early stopping
# 	0.6351	 = Validation score   (accuracy)
# 	4.66s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.6419	 = Validation score   (accuracy)
# 	3.28s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.5811	 = Validation score   (accuracy)
# 	1.74s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.5811	 = Validation score   (accuracy)
# 	2.24s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.6284	 = Validation score   (accuracy)
# 	1.41s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.6081	 = Validation score   (accuracy)
# 	60.06s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.6081	 = Validation score   (accuracy)
# 	1.43s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.6014	 = Validation score   (accuracy)
# 	1.48s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.6284	 = Validation score   (accuracy)
# 	1.49s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.6419	 = Validation score   (accuracy)
# 	11.55s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.5743	 = Validation score   (accuracy)
# 	5.03s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBMXT': 0.667, 'NeuralNetTorch': 0.333}
# 	0.6554	 = Validation score   (accuracy)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 104.53s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 3175.7 rows/s (148 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("C:\Users\ayush\OneDrive\autogluon\AutogluonModels\ag-20250116_141339")

# %%
predictor

# %%
type(predictor)
# Out:
# autogluon.tabular.predictor.predictor.TabularPredictor

# %%
predictions = predictor.predict(test_data)

# %%
evaluation = predictor.evaluate(test_data)

# %%
print("Predictions:", predictions)
print("Evaluation:", evaluation)
# Out:
# Predictions: 1      1
# 4      0
# 13     0
# 14     0
# 20     0
#       ..
# 878    1
# 896    3
# 900    0
# 912    1
# 916    0
# Name: num, Length: 184, dtype: int64
# Evaluation: {'accuracy': 0.5869565217391305, 'balanced_accuracy': 0.38115248121493295, 'mcc': 0.3949972688997073}

# %%
mydata  = predictor.leaderboard()

# %%
mydata
# Out:
#                   model  score_val eval_metric  pred_time_val   fit_time  \
# 0   WeightedEnsemble_L2   0.655405    accuracy       0.046603  14.983493
# 1            LightGBMXT   0.641892    accuracy       0.020434   3.280149
# 2        NeuralNetTorch   0.641892    accuracy       0.023168  11.545113
# 3       NeuralNetFastAI   0.635135    accuracy       0.025150   4.660862
# 4               XGBoost   0.628378    accuracy       0.011003   1.493636
# 5      RandomForestEntr   0.628378    accuracy       0.101791   1.409856
# 6              CatBoost   0.608108    accuracy       0.008121  60.063655
# 7        ExtraTreesGini   0.608108    accuracy       0.127933   1.425626
# 8        ExtraTreesEntr   0.601351    accuracy       0.130430   1.475510
# 9              LightGBM   0.581081    accuracy       0.016012   1.743920
# 10     RandomForestGini   0.581081    accuracy       0.118907   2.240339
# 11        LightGBMLarge   0.574324    accuracy       0.022287   5.034636
# 12       KNeighborsDist   0.479730    accuracy       0.028820   0.012046
# 13       KNeighborsUnif   0.445946    accuracy       0.033872   7.788532
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.003001           0.158231            2       True
# 1                 0.020434           3.280149            1       True
# 2                 0.023168          11.545113            1       True
# 3                 0.025150           4.660862            1       True
# 4                 0.011003           1.493636            1       True
# 5                 0.101791           1.409856            1       True
# 6                 0.008121          60.063655            1       True
# 7                 0.127933           1.425626            1       True
# 8                 0.130430           1.475510            1       True
# 9                 0.016012           1.743920            1       True
# 10                0.118907           2.240339            1       True
# 11                0.022287           5.034636            1       True
# 12                0.028820           0.012046            1       True
# 13                0.033872           7.788532            1       True
#
#     fit_order
# 0          14
# 1           4
# 2          12
# 3           3
# 4          11
# 5           7
# 6           8
# 7           9
# 8          10
# 9           5
# 10          6
# 11         13
# 12          2
# 13          1
